# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/data/')

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
from subprocess import check_output

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/lab experiment/sentiment analysis/Sentiment.csv')

data = data[['text','sentiment']]

data
# Out:
#                                                     text sentiment
# 0      RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1      RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2      RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3      RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4      RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive
# ...                                                  ...       ...
# 13866  RT @cappy_yarbrough: Love to see men who will ...  Negative
# 13867  RT @georgehenryw: Who thought Huckabee exceede...  Positive
# 13868  RT @Lrihendry: #TedCruz As President, I will a...  Positive
# 13869  RT @JRehling: #GOPDebate Donald Trump says tha...  Negative
# 13870  RT @Lrihendry: #TedCruz headed into the Presid...  Positive
#
# [13871 rows x 2 columns]

# %%
train, test = train_test_split(data,test_size = 0.1)

train = train[train.sentiment != "Neutral"]

# %%
train_pos = train[ train['sentiment'] == 'Positive']
train_pos = train_pos['text']
train_neg = train[ train['sentiment'] == 'Negative']
train_neg = train_neg['text']

def wordcloud_draw(data, color = 'black'):
    words = ' '.join(data)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Positive words")
wordcloud_draw(train_pos,'white')
print("Negative words")
wordcloud_draw(train_neg)
# Out:
# Positive words
# Negative words

# %%
tweets = []
stopwords_set = set(stopwords.words("english"))

for index, row in train.iterrows():
    words_filtered = [e.lower() for e in row.text.split() if len(e) >= 3]
    words_cleaned = [word for word in words_filtered
        if 'http' not in word
        and not word.startswith('@')
        and not word.startswith('#')
        and word != 'RT']
    words_without_stopwords = [word for word in words_cleaned if not word in stopwords_set]
    tweets.append((words_without_stopwords, row.sentiment))

test_pos = test[ test['sentiment'] == 'Positive']
test_pos = test_pos['text']
test_neg = test[ test['sentiment'] == 'Negative']
test_neg = test_neg['text']

# %%
tweets
# Out:
# [(['"who', 'fuck', 'john', 'kasich?"'], 'Negative'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Positive'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"-mike',
#    'huckabee'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['thought', 'seen', 'all.'], 'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['hilarity', 'aside,', 'make', 'weep', 'nationwide.'], 'Negative'),
#  (['believe',
#    'miracles"',
#    '"restore',
#    'common',
#    'sense"',
#    'bam',
#    'win!!!',
#    "that's",
#    'christian!'],
#   'Positive'),
#  (['got', 'clock', 'cleaned', 'last', 'night.', 'bye,', 'bye.'], 'Negative'),
#  (['please', 'ask', 'illegal', 'immigrants', 'work'], 'Negative'),
#  (['sadly,', "there's", 'many', 'lowinfos.', 'look', 'kanye', 'hillary.'],
#   'Negative'),
#  (['headache', 'massive', 'eye', 'roll', 'due', 'closing', 'question.'],
#   'Negative'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['dear',
#    'marco',
#    'rubio,',
#    'shut',
#    'fuck',
#    'up,',
#    'neither',
#    'entertaining',
#    'wise.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['donald',
#    'trump',
#    'always',
#    'looks',
#    'like',
#    'business',
#    'end',
#    'fart',
#    'taste.'],
#   'Negative'),
#  (['hilarious',
#    'coverage',
#    'last',
#    "night's",
#    'colleague',
#    'perrotta:',
#    'ten',
#    'guys',
#    'walk',
#    'onto',
#    'stage…'],
#   'Negative'),
#  (['got', 'like...'], 'Negative'),
#  (['god,', 'hope', 'field', 'gets', 'smaller', 'soon...'], 'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['fact', 'check:', 'gop', 'candidates', 'veer', 'truth', '1st', 'debate'],
#   'Negative'),
#  (['pro',
#    'life,',
#    'bitch',
#    'funding',
#    'programs',
#    'provide',
#    'lives???',
#    '*looking',
#    'see',
#    'at*'],
#   'Negative'),
#  (['.@chrischristie',
#    'faced',
#    '“the',
#    'hug”',
#    'problem',
#    '&amp;',
#    'responded',
#    'hugged',
#    '9/11',
#    'victims.',
#    'left',
#    'thinking,',
#    'huh?'],
#   'Negative'),
#  (['tonight',
#    'learned',
#    'thinks',
#    'remove',
#    'civil',
#    'rights',
#    'fight',
#    'terrorism.'],
#   'Negative'),
#  (['donald', 'trump', 'publicity', 'stunt', 'phase', 'right?', 'right?'],
#   'Negative'),
#  (['believe',
#    "he's",
#    'gonna',
#    'win',
#    'republican',
#    'women',
#    'support',
#    'attaching'],
#   'Negative'),
#  (['well,',
#    'over.',
#    'minds',
#    'aliens',
#    'watching',
#    'orbit,',
#    'human',
#    'species.'],
#   'Negative'),
#  (['bad',
#    'job,',
#    'reporter',
#    'never',
#    'scold',
#    '&amp;',
#    'say',
#    'things',
#    'like,',
#    '"you',
#    'mean',
#    'tell',
#    'me???"',
#    'better.'],
#   'Negative'),
#  (['unfathomable', 'would', 'ask', 'wasserman-schultz', 'postmortem'],
#   'Negative'),
#  (['packed', 'house', 'dublin', 'watch', 'party!'], 'Positive'),
#  (['srsly',
#    'america,',
#    'give',
#    'one',
#    'guys',
#    'launch',
#    'code',
#    'nukes',
#    'live',
#    'right',
#    'flightpath,',
#    '*please*'],
#   'Negative'),
#  (['need',
#    'order',
#    'another',
#    'green',
#    'apple',
#    'martini',
#    'process',
#    'hell',
#    'happened.'],
#   'Negative'),
#  (['"i\'m',
#    'different',
#    'kind',
#    'republican"',
#    'really',
#    'needs',
#    'show',
#    'contrast,',
#    'instead',
#    'panderi…'],
#   'Positive'),
#  (['impressive', 'performance', 'governor', 'huckabee!'], 'Positive'),
#  (['trump',
#    'got',
#    'right,',
#    'nobody',
#    'would',
#    'talk',
#    'immigration,',
#    'untill',
#    'brought',
#    'up.'],
#   'Positive'),
#  (['rosie', "o'donnell."], 'Negative'),
#  (['kasich',
#    'enough',
#    'sociopath',
#    'kill',
#    'useless',
#    'eaters',
#    'type',
#    'gop',
#    'nominee.'],
#   'Negative'),
#  (['"we\'ve',
#    'lied',
#    'to,',
#    'need',
#    'strong',
#    'leader',
#    'tell',
#    'truth."',
#    '-@chrischristie'],
#   'Negative'),
#  (['calling',
#    'women',
#    'dehumanizing',
#    'names',
#    'lack',
#    'political',
#    'correctness,',
#    'lack',
#    'basic',
#    'decency',
#    'respect.'],
#   'Negative'),
#  (['creepy', 'blond', 'commentator', 'promised', 'coming', 'break.'],
#   'Negative'),
#  (['lol',
#    'republican',
#    'love',
#    'carson.',
#    'racism',
#    'loves',
#    'black',
#    'man',
#    'submits!',
#    "let's",
#    'stop'],
#   'Negative'),
#  (['bad', 'attacked', 'moderator', 'even', 'respond', 'question.'],
#   'Negative'),
#  (['summer',
#    'fun',
#    "i'm",
#    'quite',
#    'sure',
#    'feel',
#    'fact',
#    'august.',
#    'politics',
#    'makes',
#    'worse\U000fe320\U000fe327'],
#   'Negative'),
#  (['pro-life',
#    'include',
#    'lives',
#    'school',
#    'kids',
#    'fetuses?',
#    'support',
#    'public',
#    'schools?'],
#   'Negative'),
#  (['ben', 'damn', 'funny!'], 'Positive'),
#  (['bullshit.', 'needed', 'hip', 'high', 'waders', 'get', 'first'],
#   'Negative'),
#  (['fyi', 'defense', 'spending', 'compared', 'countries'], 'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['one',
#    'candidate',
#    'spoke',
#    "trump's",
#    'mass-deportation',
#    'plan,',
#    '&amp;',
#    'one',
#    'condemned',
#    'racist',
#    'comments.',
#    'latinos',
#    'forget…'],
#   'Negative'),
#  (['hug?', 'thought', 'punched.', 'or,', 'guess', "that's", 'teachers.'],
#   'Negative'),
#  (['damn', 'christian', 'revival.', 'cut', 'out.'], 'Negative'),
#  (['sympathize',
#    'child',
#    'molestors"',
#    'assume',
#    'saying',
#    'anytime',
#    'mouth',
#    'opens'],
#   'Negative'),
#  (['explains', 'campaign', 'finance', 'lat', 'night.', 'insightful', 'piece'],
#   'Positive'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['trumptastic'], 'Positive'),
#  (['dear',
#    'marco',
#    'rubio,',
#    'shut',
#    'fuck',
#    'up,',
#    'neither',
#    'entertaining',
#    'wise.'],
#   'Negative'),
#  (['takeaway',
#    'believes',
#    'live',
#    'terrible',
#    'apocalyptic',
#    'world,',
#    'surrounded',
#    'scary',
#    'people.',
#    'sad.'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['carly', 'fiorina', 'time', 'loser'], 'Negative'),
#  (['xm121', 'today', '3-4pm', 'fun', 'always', 'great'], 'Positive'),
#  (['would',
#    'like',
#    'add',
#    'separation',
#    'church',
#    'state,',
#    'needs',
#    'stay',
#    'way.'],
#   'Negative'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"-mike',
#    'huckabee'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['chadstanton:', 'brownblaze:', 'please', 'rt.'], 'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['.@speakerboehner',
#    'time',
#    'evolve',
#    'sir!',
#    '(yes,',
#    'real,',
#    'too.',
#    ';-)'],
#   'Negative'),
#  (['quite',
#    'something',
#    'watch',
#    'canadian',
#    'debate.',
#    'anyone',
#    'take',
#    'american',
#    'politicians',
#    'seriously?'],
#   'Negative'),
#  (['btw',
#    'correct',
#    'response',
#    'last',
#    "night's",
#    "would've",
#    'been:',
#    '"my',
#    'faith',
#    'personal',
#    'matter',
#    '&amp;',
#    'unrelated',
#    'aptitude',
#    'statesman"'],
#   'Negative'),
#  (['deserves',
#    'big',
#    'thank',
#    'you.',
#    "i'm",
#    'glad',
#    'someone',
#    'asked',
#    'tough',
#    'questions--to',
#    'candidates.'],
#   'Positive'),
#  (['solution', 'everything', 'war.'], 'Negative'),
#  (['believing',
#    'fans',
#    'say',
#    '&amp;',
#    'losing',
#    'touch',
#    'w/reality.',
#    'sorry,',
#    'woefully',
#    'unnewsworty',
#    'moderation',
#    'job'],
#   'Negative'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['businessman', 'seriously', 'irritating', 'bias.'], 'Negative'),
#  (['tame',
#    'reporting',
#    'bbc.',
#    'must',
#    'best',
#    '"show"',
#    'last',
#    'night!',
#    'wish',
#    "i'd",
#    'seen',
#    'it!'],
#   'Negative'),
#  (["i'm", 'waiting', 'accidentally', 'eat'], 'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Positive'),
#  (['rwnjs',
#    'upset',
#    'fox',
#    'lobbing',
#    'softballs',
#    'favorites.',
#    'bunch',
#    'babies.'],
#   'Negative'),
#  (['take',
#    'true',
#    'debate.',
#    'except',
#    'handful',
#    'onstage',
#    'battles',
#    'really',
#    'people',
#    'answering',
#    'questions'],
#   'Negative'),
#  (["there's",
#    'difference',
#    'policies',
#    'candidates',
#    'stand',
#    'for.',
#    "they're",
#    'singing',
#    'songbook.',
#    'bad',
#    'son…'],
#   'Negative'),
#  (["i'm", 'expecting', 'guy', 'walk', 'moment'], 'Negative'),
#  (['moment', 'realize', 'watching', 'fox', 'news', 'handcuffs.'], 'Negative'),
#  (['going', 'ask', 'policy', 'questions?', 'character', 'smears?'],
#   'Negative'),
#  (['american',
#    'voters',
#    'deserved',
#    'better',
#    'questions',
#    'knew',
#    'better...'],
#   'Negative'),
#  (['walker:', 'god', 'cutting', 'budget.', 'talk', 'him.'], 'Negative'),
#  (['cruz',
#    'disrespected?',
#    'trump',
#    'disrespected.',
#    'seems',
#    'fox',
#    'likes',
#    'rhinos',
#    'days!'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['wandered',
#    'away',
#    'coverage',
#    'last',
#    'night,',
#    'shouting',
#    'evens',
#    "can't"],
#   'Negative'),
#  (['media',
#    'call',
#    'carly',
#    'fiorina',
#    'female',
#    'gop',
#    'candidate?',
#    'democrats',
#    'one?',
#    'anyone',
#    'white?'],
#   'Negative'),
#  (['.@cnn',
#    'breaking',
#    'debate',
#    'fact',
#    'checks,',
#    'good',
#    'see',
#    'media',
#    'actually',
#    'holding',
#    'candidates',
#    'accountable.'],
#   'Positive'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Negative'),
#  (['translation,',
#    'jeb',
#    'bush,',
#    'fucked',
#    'florida',
#    'schools',
#    'badly',
#    'still',
#    'recovered.',
#    'truth,',
#    'live',
#    'here…'],
#   'Negative'),
#  (['taught',
#    'okay',
#    'mean',
#    'others',
#    'reframe',
#    'anti-political',
#    'correctness'],
#   'Positive'),
#  (['bring', 'back', "i'm", 'bored', 'now!'], 'Positive'),
#  (['considering',
#    'debate',
#    'was,',
#    "can't",
#    'blame',
#    'them!',
#    'might',
#    'need',
#    'join',
#    'them!',
#    'thanks'],
#   'Negative'),
#  (['me,',
#    'guy',
#    'like',
#    'me?',
#    'going',
#    'run',
#    'president',
#    'republican',
#    'better',
#    'seat',
#    'debate.'],
#   'Negative'),
#  (['bushs...', 'fuck', 'jeb'], 'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['torched',
#    'passed',
#    '-&gt;.@candycrowley',
#    'longer',
#    'famous',
#    'political',
#    'assassin!',
#    'congratulations',
#    'wi…'],
#   'Negative'),
#  (['gets', 'vote', 'tonight,', 'dr.', 'carson', 'close', 'second.'],
#   'Positive'),
#  (['jeb',
#    'stands',
#    '"act',
#    'love";',
#    'comments',
#    'earned',
#    'legal',
#    'status',
#    '[boo]'],
#   'Positive'),
#  (['ridiculous', 'things', 'said'], 'Negative'),
#  (['.@govchristie', 'got', 'ass', 'served'], 'Negative'),
#  (['caught', 'hour', 'frankensteins', 'singing', '"puttin\'', 'ritz".'],
#   'Negative'),
#  (['walker,', 'surprisingly,', 'gets', '(mostly)', 'right.'], 'Positive'),
#  (['imho', 'winners', 'losers', 'others', 'completely', 'forgettable'],
#   'Positive'),
#  (['embarrassment.', 'wonder', 'know', 'bad', 'looked', 'rest', 'world?'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['intern',
#    '"this',
#    'lady',
#    'kept',
#    'asking',
#    'questions',
#    'gay',
#    'rights',
#    'lesbians',
#    "women's",
#    'rights.',
#    'ridiculous."'],
#   'Negative'),
#  (['paul',
#    'krugman',
#    'sums',
#    'happended',
#    'last',
#    'night:',
#    '"one',
#    'two',
#    'major',
#    'parties',
#    'gone',
#    'deep',
#    'end"'],
#   'Negative'),
#  (['.@foxnews',
#    'hard',
#    'time',
#    'covering',
#    '.@megynkelly',
#    'put',
#    'colleagues',
#    'bad',
#    'spot.'],
#   'Negative'),
#  (['country',
#    'mess',
#    '"mods"',
#    'attack',
#    'personal',
#    'hate.',
#    'makes',
#    'sad',
#    'american.#gopdebate'],
#   'Negative'),
#  (['glenn',
#    'beck',
#    'saying',
#    'rand',
#    'big',
#    'winner',
#    'christie',
#    'big',
#    'loser.'],
#   'Positive'),
#  (['bottom', 'line', 'vote', 'candidates', 'last', 'night'], 'Positive'),
#  (['true.', 'disrespected', 'cruz', 'eve'], 'Negative'),
#  (['pulling', 'trump', 'like', '"minions"', 'candidates'], 'Positive'),
#  (['wwahammy:',
#    'jrehling:',
#    'donald',
#    'trump',
#    'says',
#    'time',
#    'political',
#    'correctness.'],
#   'Negative'),
#  (['omg!!!', 'favorite', 'thing.'], 'Positive'),
#  (['believing',
#    '"god"',
#    'prerequisite',
#    'office',
#    'presidency.',
#    'talking',
#    'it?'],
#   'Negative'),
#  (['hey',
#    'planning',
#    'giving',
#    'chance',
#    'speak?',
#    'trying',
#    'marginalize',
#    'daily',
#    'news'],
#   'Positive'),
#  (['embarrassment'], 'Negative'),
#  (['trump', 'democrat', '‘wolf’', 'gop', 'clothing?'], 'Negative'),
#  (['gurrrrrlll!'], 'Positive'),
#  (['total',
#    'theatre',
#    'fox',
#    'news',
#    'tonight,',
#    'basis',
#    'fact',
#    'all...',
#    'garbage.'],
#   'Negative'),
#  (['well,',
#    'watching',
#    'decided',
#    'voting',
#    'candidates',
#    'need',
#    'watch',
#    'another'],
#   'Negative'),
#  (['disappointed',
#    'treated',
#    'different',
#    'would',
#    'have;',
#    'dictating',
#    'repo…'],
#   'Negative'),
#  (['blog:',
#    'god',
#    'made',
#    'cameo',
#    'appearance',
#    'last',
#    "night's",
#    "we're",
#    'sure',
#    'come.'],
#   'Positive'),
#  (['carson,',
#    'carson,',
#    'carson:',
#    'dammit',
#    'man!',
#    'say',
#    'words',
#    'racism',
#    'white',
#    'supremacy',
#    'audience!'],
#   'Negative'),
#  (['anybody',
#    'see',
#    "trump's",
#    'face',
#    'rubio',
#    'mentioned',
#    'last',
#    'night?',
#    'horror.'],
#   'Negative'),
#  (['oompa', 'loompa?'], 'Negative'),
#  (['commercial', 'break!'], 'Negative'),
#  (['so,',
#    'trump',
#    'buys',
#    'politicians,',
#    'used',
#    'bankruptcy',
#    'advantage,',
#    'skirted',
#    'laws',
#    'money,',
#    'admitted',
#    'wanting',
#    'single',
#    'payer'],
#   'Negative'),
#  (['megyn', "kelly's", 'hair', 'extensions', 'excellent', 'job', 'tonight!'],
#   'Negative'),
#  (["can't",
#    'believe',
#    'people',
#    'writing',
#    'real',
#    'articles',
#    '*all*',
#    'lost'],
#   'Negative'),
#  (['know',
#    'someone',
#    'finalized',
#    'amount',
#    'time',
#    'candidate',
#    'speak,',
#    'send',
#    'pls!'],
#   'Negative'),
#  (['fucking', 'dickshits', 'planned', 'parenthood', 'abortion', 'emporium.'],
#   'Negative'),
#  (["here's", 'facts.', 'check', 'out.'], 'Positive'),
#  (['candidates',
#    'makes',
#    'interesting',
#    'change!',
#    'top',
#    'moments',
#    "thursday's",
#    'debate'],
#   'Positive'),
#  (['leader',
#    'integrity',
#    'country',
#    'beg',
#    'god',
#    'for.',
#    'get',
#    'one',
#    'upright?!!!'],
#   'Negative'),
#  (['fetus',
#    'dies',
#    'womb',
#    'weeks?',
#    'd&amp;c',
#    'you.',
#    'thinks',
#    'carry',
#    'full',
#    'term.'],
#   'Negative'),
#  (['"where',
#    'think',
#    'women',
#    'sleep',
#    'curse?',
#    'shed?',
#    'open',
#    'field,',
#    "property?'"],
#   'Negative'),
#  (['paul/christie', 'debate', 'hurt', 'candidates.'], 'Negative'),
#  (['"what', 'black', 'liv-......', "let's", 'cut', 'commercial."'],
#   'Negative'),
#  (['"destroying',
#    'isis',
#    'days"',
#    'sounds',
#    'like',
#    'movie',
#    "i'd",
#    'pay',
#    'see'],
#   'Negative'),
#  (['misogynist,',
#    'ignorant,',
#    'xenophobic',
#    'greedy:',
#    'another',
#    'proof',
#    'money',
#    'buy',
#    'class.'],
#   'Negative'),
#  (['one',
#    'favorite',
#    'things',
#    'many',
#    'candidates',
#    "i've",
#    'seen',
#    'person.',
#    'thanks',
#    '&amp;'],
#   'Positive'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['blogger',
#    'debate',
#    'making',
#    'sure',
#    'donald',
#    'trump',
#    'pull',
#    'rose',
#    'perot,',
#    'clinton'],
#   'Negative'),
#  (['head',
#    'republican',
#    'party',
#    'recently',
#    'said',
#    'party',
#    'longer',
#    'win',
#    'national',
#    'election.',
#    'tonight’s',
#    'confi…'],
#   'Negative'),
#  (['ben',
#    'carson',
#    'never',
#    'talked',
#    'elementary',
#    'schools',
#    'black',
#    'history',
#    'month',
#    'ever',
#    'again,',
#    'dawg.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['senator',
#    'cruz,',
#    'word',
#    'god?',
#    'spit',
#    'tequila.',
#    'damn',
#    'megyn',
#    'kelly,',
#    'expensive',
#    'kind.'],
#   'Negative'),
#  (['weird.', 'clear', 'winner.'], 'Negative'),
#  (["morning's", 'reactions', 'show'], 'Negative'),
#  (['vote',
#    'me:',
#    'greatest',
#    'time',
#    'alive',
#    'dont',
#    'know',
#    'primary',
#    'jeb',
#    'bush'],
#   'Positive'),
#  (['good',
#    'job,',
#    'stooped',
#    'level',
#    'two',
#    'biggest',
#    'jack',
#    'asses',
#    '"entertainment"👏🏼'],
#   'Negative'),
#  (['dear',
#    'nobody',
#    'likes',
#    'abortion,',
#    'want',
#    'republicans',
#    'raping',
#    'children',
#    'getting',
#    'away',
#    'it.'],
#   'Negative'),
#  (['in:',
#    'without',
#    'god',
#    'become',
#    'childless',
#    'alcoholic',
#    'lot',
#    'free',
#    'time.',
#    'sign',
#    'up.'],
#   'Negative'),
#  (['headed', 'presidential', 'debates.', 'ted!!'], 'Positive'),
#  (['libertarian',
#    'hate',
#    'state',
#    'power?',
#    'right?',
#    'silent',
#    'volume',
#    'mute?'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['"we\'re', 'borrowing', '$1m', 'minute.', 'gotta', 'stop', 'somewhere."'],
#   'Positive'),
#  (['today',
#    'time',
#    'next',
#    'president',
#    'one',
#    'year',
#    'office',
#    'empty',
#    'arena.'],
#   'Positive'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"-mike',
#    'huckabee'],
#   'Negative'),
#  (['brief',
#    'mentions,',
#    '&amp;',
#    'bush',
#    'support',
#    'keystone',
#    'xl,',
#    'oil,',
#    'energy,',
#    'climate,',
#    'environment,',
#    'etc.',
#    'played',
#    'role'],
#   'Negative'),
#  (['headed', 'presidential', 'debates.', 'ted!!'], 'Positive'),
#  (['rubio',
#    'best',
#    'attack',
#    'night',
#    'marco',
#    'rubio',
#    'hillary',
#    'clinton',
#    '...'],
#   'Positive'),
#  (['.@ivankatrump',
#    'call',
#    'father',
#    're:',
#    'comments',
#    'supposedly',
#    'listens',
#    'you.',
#    'shameful.',
#    'got',
#    'daughters.'],
#   'Negative'),
#  (['better', 'phantom', 'menace,', 'worse', 'revenge', 'sith.'], 'Negative'),
#  (['ted', 'cruz', 'thinks', 'birth', 'control', '“abortion-inducing', 'drug”'],
#   'Negative'),
#  (['winners',
#    ':cruz',
#    '&amp;',
#    'carly',
#    'also',
#    'rubio,',
#    'walker',
#    'jindal',
#    'extremely',
#    'disappointed',
#    'chris',
#    'wallace'],
#   'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['loved',
#    'pointed',
#    'ronald',
#    'reagan',
#    'evolved,',
#    'he--i',
#    'think',
#    'like'],
#   'Positive'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['kim',
#    'kardashian',
#    'kanye',
#    "west's",
#    'selfie',
#    'hillary',
#    'clinton',
#    'important',
#    'anything',
#    'said'],
#   'Positive'),
#  (['american',
#    'women:',
#    'scott',
#    'walker',
#    'thinks',
#    'fetus',
#    'live,',
#    'die.',
#    'rubio',
#    'thinks',
#    'bear',
#    "rapist's"],
#   'Negative'),
#  (['slash', 'said,', 'chris', 'christie', '......', 'never', 'president'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['boy:',
#    '"social',
#    'issues"',
#    'gop',
#    'code',
#    'control',
#    "women's",
#    'bodies',
#    '&amp;',
#    'sexuality',
#    'most.',
#    'hold',
#    'tight,',
#    'twitterland'],
#   'Negative'),
#  (['guys', 'write', 'snl.', 'even', 'kidding.'], 'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['fact',
#    'jeb',
#    'support',
#    "brother's",
#    'decision',
#    'iraq',
#    'something',
#    'like.',
#    'back',
#    'family.'],
#   'Negative'),
#  (["can't",
#    'stand',
#    'much',
#    'more.',
#    'best',
#    'gop,',
#    'love',
#    'chances',
#    '2016'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['politicians',
#    'former',
#    'government',
#    'employees',
#    'really',
#    'hate',
#    'politicians',
#    'government.'],
#   'Negative'),
#  (['rubio',
#    'thinks',
#    'republican',
#    'party',
#    'bffs',
#    'god',
#    'democrats',
#    'suck',
#    'god',
#    'hates',
#    'them.'],
#   'Negative'),
#  (['.@instagram',
#    'need',
#    'free',
#    'acct.',
#    'legitimate',
#    'convo',
#    'highlighting',
#    'real',
#    'concerns.'],
#   'Negative'),
#  (['marco', 'rubio', 'wear', 'invisalign?'], 'Negative'),
#  (['worst!', 'appreciate', 'theatrics', "that's", 'about!'], 'Negative'),
#  (['“@johnfugelsang', 'nothing', 'new.', 'old', 'song', 'dance.'], 'Negative'),
#  (['two', 'debates,', 'one', 'winner:', 'carly'], 'Positive'),
#  (["here's", 'part', 'try', 'prove', "they're", 'biggest', 'misogynist.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['trump', 'companies', 'went', 'bankrupt,', 'wants', 'fix', 'u.s.', 'debt?'],
#   'Negative'),
#  (['kayleymelissa:',
#    'like',
#    'trial',
#    'unbreakable',
#    'kimmy',
#    'schmidt',
#    'dona…'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['showed',
#    'gop',
#    'candidates',
#    'touch',
#    'workers,',
#    'women,',
#    'people',
#    'color',
#    'basically',
#    'anyo…'],
#   'Negative'),
#  (['men', 'stage', 'discussing', 'one', 'woman.'], 'Negative'),
#  (['everyone',
#    'still',
#    'talking',
#    'great',
#    'job',
#    'last',
#    'night.',
#    'articulate',
#    'good',
#    'points',
#    'made.',
#    '👍🏼👍🏼👍🏼'],
#   'Positive'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['small',
#    'window',
#    'tonight.',
#    'soft',
#    'side.',
#    '"nice,',
#    'class',
#    'act,',
#    'respectful',
#    '&amp;',
#    'fair"',
#    'matters',
#    'him.'],
#   'Positive'),
#  (['fact:', 'jeb', 'governor,', 'florida', 'run', 'death', 'cult.'],
#   'Negative'),
#  (["i'm",
#    'really',
#    'hard',
#    'time',
#    'thinking',
#    'ways',
#    'could',
#    'successful',
#    'shenanigans'],
#   'Positive'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['busy',
#    'convincing',
#    'american',
#    'nightmare,',
#    'forgotten',
#    'engage',
#    'american',
#    'dream.'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['jon',
#    'stewart',
#    'quits',
#    'day',
#    'feel',
#    'like',
#    'going',
#    'miss',
#    'greatest',
#    'comedic',
#    'election',
#    'time.'],
#   'Negative'),
#  (['.@realdonaldtrump:',
#    'weren’t',
#    'wouldn’t',
#    'even',
#    'talking',
#    'illegal',
#    'immigration'],
#   'Negative'),
#  (['moment', 'graduated', 'high', 'school', 'watch', ':))'], 'Positive'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['pffft.',
#    'since',
#    'fox',
#    'care',
#    'lady',
#    'viewers?',
#    'plus,',
#    "megyn's",
#    'sole',
#    'goal',
#    'come',
#    'winner.'],
#   'Negative'),
#  (['featured',
#    'true',
#    '"confederacy',
#    'dunces"--',
#    'group',
#    'dunces',
#    'want',
#    'revive',
#    'confederacy.'],
#   'Negative'),
#  (['unplanned', 'parenthood.'], 'Negative'),
#  (['yes,', 'respect', 'like', 'saying', 'punch', 'people', 'faces!'],
#   'Negative'),
#  (['lmfao',
#    'rofl',
#    'hahahaha.',
#    'give',
#    'see',
#    '1980s',
#    'shit',
#    'lord',
#    'ron',
#    'paul',
#    'stage.'],
#   'Negative'),
#  (['could', 'actually', 'democrat', 'trying', 'help', 'democrats?'],
#   'Negative'),
#  (['fox',
#    'news',
#    'agenda:',
#    'promote',
#    'carly',
#    '"never',
#    'mention',
#    'fired',
#    'hp"',
#    'fiorina,',
#    '&amp;',
#    'run',
#    'trump',
#    'race'],
#   'Negative'),
#  (['disappoint', '...', 'unless', 'hoping', 'actual', 'debate.'], 'Negative'),
#  (['refreshing.'], 'Negative'),
#  (['take',
#    "christie's",
#    'performance',
#    'last',
#    "night's",
#    'came',
#    'irrelevant',
#    '&amp;',
#    'peripheral'],
#   'Negative'),
#  (['frightening...', 'yet', "can't", 'look', 'away!'], 'Negative'),
#  (['huck', 'say', 'wants', 'protect', 'benefits', 'pimps', 'prostitutes?'],
#   'Negative'),
#  (['watched',
#    'part',
#    'last',
#    'night.',
#    'hilarious',
#    'thinks',
#    'chance.',
#    'let',
#    'alone',
#    'th…'],
#   'Negative'),
#  (['one',
#    'favorite',
#    'things',
#    'many',
#    'candidates',
#    "i've",
#    'seen',
#    'person.',
#    'thanks',
#    '&amp;'],
#   'Positive'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['foxnews',
#    'long-game',
#    'liberal',
#    'conspiracy',
#    'drive',
#    'republican',
#    'party',
#    'far',
#    'right',
#    'never',
#    'win',
#    'general',
#    'election?'],
#   'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['(vine'], 'Negative'),
#  (['said', 'mouthful.'], 'Positive'),
#  (["who's",
#    '"marginalizing"',
#    'women',
#    'lingerie',
#    'model',
#    'glass',
#    'houses?'],
#   'Negative'),
#  (['"@foxnews', 'web', 'stream', 'mobile', 'app', 'fail', 'surprised?'],
#   'Negative'),
#  (['ahead', 'watch', 'change', 'couple', 'seconds.'], 'Negative'),
#  (['based',
#    'rhetoric,',
#    'assume',
#    'donald',
#    'trump',
#    'looks',
#    'megyn',
#    'kelly,',
#    'sees',
#    'miss',
#    'piggy.'],
#   'Negative'),
#  (['planned',
#    'parenthood',
#    'takes',
#    'care',
#    'many',
#    'things',
#    'abortions',
#    'wtf.'],
#   'Negative'),
#  (['snapchat',
#    'jeb',
#    'says',
#    'people',
#    'way',
#    'better',
#    'hillary',
#    'bernie.',
#    'couldnt',
#    'help',
#    'laugh.'],
#   'Negative'),
#  (['closing', 'statements!'], 'Negative'),
#  (['winners',
#    'imo:',
#    'marco',
#    'rubio,',
#    'rand',
#    'paul,',
#    'john',
#    'kasich',
#    'carly',
#    'fiorina'],
#   'Positive'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['watching', 'republican', 'party', 'implode', 'within', 'magical.'],
#   'Negative'),
#  (['award',
#    'disingenuous',
#    'statement',
#    'last',
#    "night's",
#    'goes',
#    'doubletalk:'],
#   'Negative'),
#  (['rand', 'paul', '“the', 'dnc’s', 'top', 'target”?', 'read', 'here:'],
#   'Negative'),
#  (['megyn',
#    'kelly',
#    'chris',
#    'wallace',
#    'brett',
#    'bair',
#    'doubt',
#    'posing',
#    'questions',
#    'incite',
#    'attacks',
#    'drama..and',
#    'backfired'],
#   'Negative'),
#  (['lindsey', 'graham', 'could', 'solution', 'insomniacs', 'everywhere.'],
#   'Negative'),
#  (['wonder',
#    'address',
#    'actual',
#    'solutions',
#    'climate',
#    'change',
#    'clean',
#    'energy.'],
#   'Negative'),
#  (['miss',
#    'format',
#    'cnn/youtube',
#    '07!',
#    'fun,',
#    'informative--bring',
#    'back!'],
#   'Positive'),
#  (['so,',
#    'trump',
#    'buys',
#    'politicians,',
#    'used',
#    'bankruptcy',
#    'advantage,',
#    'skirted',
#    'laws',
#    'money,',
#    'admitted',
#    'wanting',
#    'single',
#    'payer'],
#   'Negative'),
#  (['richierichbor:',
#    'diabetesheroes:',
#    'like',
#    'disney',
#    'movie.',
#    'looked',
#    'frozen,',
#    'megyn',
#    'kelly',
#    '&amp;',
#    'tr…'],
#   'Negative'),
#  (['funny',
#    'trying',
#    'watch',
#    'people',
#    'act',
#    'smart',
#    'talking',
#    'clearly',
#    'know',
#    'nothing.'],
#   'Negative'),
#  (['newsflash,', 'jeb', 'unite', 'country', 'please!', 'lol!'], 'Negative'),
#  (['going',
#    'ask',
#    'lenny',
#    "kravitz's",
#    'penis',
#    'one',
#    'question?',
#    'disrespectful.'],
#   'Negative'),
#  (['detailed',
#    'policy',
#    'proposal',
#    'got',
#    'ben',
#    "carson's",
#    'idea',
#    'destroy',
#    'america.'],
#   'Negative'),
#  (['11:11',
#    '(and',
#    'please',
#    'let',
#    'better',
#    'future',
#    'leaders',
#    'country',
#    'watching'],
#   'Negative'),
#  (['support',
#    'eventual',
#    'gop',
#    'candidate',
#    'bernie',
#    'socialist,',
#    'hillary',
#    'habitual',
#    'liar',
#    'biden',
#    'buffoon.'],
#   'Positive'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['think', 'cent', 'titanium', 'tax', 'far', 'enough!'], 'Negative'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Negative'),
#  (['seem',
#    'even',
#    'candidates',
#    'praised',
#    '"sticking',
#    'question"',
#    'still',
#    'kind',
#    'run',
#    'around',
#    'it?'],
#   'Negative'),
#  (['perfect', 'summation'], 'Negative'),
#  (['boy:',
#    '"social',
#    'issues"',
#    'gop',
#    'code',
#    'control',
#    "women's",
#    'bodies',
#    '&amp;',
#    'sexuality',
#    'most.',
#    'hold',
#    'tight,',
#    'twitterland'],
#   'Negative'),
#  (['miss',
#    'days',
#    'conservatives',
#    'wanted',
#    'presidential',
#    'candidate',
#    'was,',
#    'know,',
#    'conservative...'],
#   'Negative'),
#  (['shocking', 'photo', 'taken', 'sewers', 'ohio', 'last', 'night.'],
#   'Negative'),
#  (['long-shot',
#    'republican',
#    'nomination',
#    'chose',
#    'running',
#    'mate,',
#    "he'd",
#    'vote.'],
#   'Positive'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['obamacare',
#    'extends',
#    'solvency',
#    'medicare',
#    'makes',
#    'prescription',
#    'drugs',
#    'affordable.',
#    "that's",
#    'care',
#    'seniors',
#    'deserve.'],
#   'Negative'),
#  (['really',
#    'fair',
#    'trump',
#    'among',
#    'gop',
#    'candidates',
#    'money',
#    'buy',
#    'anything',
#    'even',
#    'results'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Positive'),
#  (['trump:', 'told', 'god', 'come', 'wedding', 'came.'], 'Negative'),
#  (['one',
#    'white',
#    'woman',
#    'killed',
#    'illegal',
#    'immigrant?',
#    'law?',
#    'black',
#    'women',
#    'die',
#    'police',
#    'custody?',
#    '"all',
#    'lives',
#    'matter…'],
#   'Negative'),
#  (['rand',
#    'paul:',
#    'want',
#    'marriage',
#    'guns',
#    'registered',
#    'dc.',
#    'now,',
#    'stage',
#    'packing?',
#    'denny',
#    'crane'],
#   'Negative'),
#  (['noticed', 'too!', 'keep', 'starting', 'bush', 'grr'], 'Negative'),
#  (["i'm",
#    'conservatives',
#    'supports',
#    'rinos',
#    'like',
#    'bush,',
#    'huckabee,',
#    'rubio',
#    '&amp;',
#    'santorum'],
#   'Negative'),
#  (['chris', 'cristie', 're:', 'abortions?', 'absurd.'], 'Negative'),
#  (['tonight',
#    'learned',
#    'thinks',
#    'remove',
#    'civil',
#    'rights',
#    'fight',
#    'terrorism.'],
#   'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['gives', 'fox,', 'speaking', 'time', 'first', 'debate', 'via', '&amp;'],
#   'Negative'),
#  (['changes/benefits/incentives/breaks',
#    "gov't",
#    'parents',
#    'choose',
#    'be...'],
#   'Negative'),
#  (['every',
#    'time',
#    'camera',
#    'cuts',
#    'trump,',
#    "he's",
#    'grimacing',
#    'like',
#    "he's",
#    'trying',
#    'break',
#    'wind',
#    'avoid',
#    'shart...'],
#   'Negative'),
#  (['disappointed.', 'one', 'said', '"churchillian."'], 'Negative'),
#  (['yes',
#    'goyim,',
#    'communist',
#    'sympathizer',
#    'approves',
#    'plz',
#    'stop',
#    'racist',
#    'htt…'],
#   'Negative'),
#  (['(painful)',
#    '(that',
#    'embarrass',
#    'americans)',
#    'shows',
#    'gop',
#    'dumb',
#    'even',
#    'know',
#    'biggest',
#    'th…'],
#   'Negative'),
#  (['trump', 'cam', 'hands.'], 'Positive'),
#  (['winner', 'is...', 'koch', 'brothers'], 'Positive'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['someone', 'tell', 'gop', '"i-ran"....'], 'Negative'),
#  (['.@instagram',
#    'need',
#    'free',
#    'acct.',
#    'legitimate',
#    'convo',
#    'highlighting',
#    'real',
#    'concerns.'],
#   'Negative'),
#  (['misogyny',
#    'surprise',
#    'considering',
#    'men',
#    'stage,',
#    'pontificating',
#    'bodies'],
#   'Negative'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['tonight',
#    'learned',
#    'thinks',
#    'remove',
#    'civil',
#    'rights',
#    'fight',
#    'terrorism.'],
#   'Negative'),
#  (['"hey,',
#    'guys.',
#    'women',
#    'allowed',
#    'vote."',
#    '"what?"',
#    '"that\'s',
#    'impossible!"',
#    '"build',
#    'wall',
#    'around',
#    'uterus!"',
#    '"ronald',
#    'reagan…'],
#   'Negative'),
#  (['trump:', 'system', 'broken,', 'know', "i've", 'taken', 'advantage.'],
#   'Negative'),
#  (['fact:', 'scott', 'walker', 'lies', 'often', 'tells', 'truth'], 'Negative'),
#  (['lots',
#    'positives',
#    '&amp;',
#    'negatives',
#    'last',
#    "night's",
#    'candidate',
#    'bring',
#    '&amp;'],
#   'Positive'),
#  (['last',
#    'night',
#    'clarified',
#    'clown',
#    'car,',
#    'loony',
#    'van',
#    'sociopaths.'],
#   'Negative'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['analysis,',
#    '10)',
#    'gov.',
#    'kasich',
#    'rising',
#    'star',
#    'republican',
#    'politics,',
#    'shows',
#    'strong',
#    'leadership,',
#    'definitel…'],
#   'Positive'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Negative'),
#  (['many', 'great', 'jokes', 'twitter', 'tonight', 'many', 'stage.'],
#   'Negative'),
#  (['new',
#    'hampshire',
#    'poll:',
#    'paul',
#    'leads',
#    'hillary',
#    '2%,',
#    'trump',
#    'losing',
#    '10%'],
#   'Positive'),
#  (['think',
#    'ppl',
#    'america',
#    'understand',
#    'people,',
#    'government',
#    'creates',
#    'job”'],
#   'Positive'),
#  (['facebook',
#    'says',
#    'top',
#    'social',
#    'moment',
#    'chris',
#    'christie-rand',
#    'paul',
#    'interaction',
#    'nsa'],
#   'Positive'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Negative'),
#  (['obvious,',
#    'last',
#    "night's",
#    'sealed',
#    'deal.',
#    'amazing.',
#    'shande',
#    'democracy'],
#   'Negative'),
#  (['maryland,',
#    'didn’t',
#    'wait',
#    'federal',
#    'gov',
#    'act,',
#    'passed',
#    'dream',
#    'act.'],
#   'Negative'),
#  (['american',
#    'people',
#    'pick',
#    'next',
#    'president',
#    'united',
#    'states',
#    'fox',
#    'news'],
#   'Negative'),
#  (['politically',
#    'correct',
#    'way',
#    'say',
#    'america',
#    'failing',
#    'current',
#    'leadership.',
#    'deadbeat',
#    'nation',
#    'change.'],
#   'Negative'),
#  (['word',
#    'god',
#    'worse',
#    'question',
#    'night.',
#    'waste',
#    'time',
#    'many',
#    'important',
#    'issues'],
#   'Negative'),
#  (['no,',
#    'scott',
#    'walker,',
#    '"lash"',
#    'protesters',
#    'wisconsin...',
#    'arrested.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['walker:', 'god', 'cutting', 'budget.', 'talk', 'him.'], 'Negative'),
#  (['christie:', 'putting', 'america', 'risk', 'fourth', 'amendment', 'talk'],
#   'Negative'),
#  (["morning's", 'recap', 'elephants', 'room,', 'best', 'recap', 'time'],
#   'Negative'),
#  (['"lying', 'stealing', 'american', 'public', 'already', 'occurred."'],
#   'Negative'),
#  (['.@gatewaypundit',
#    'megyn=',
#    'new',
#    'candy',
#    'crowley.',
#    'blundered',
#    'badly.',
#    'fox',
#    'exposed',
#    'themselves.'],
#   'Negative'),
#  (["i'm", 'really', 'really', 'really', 'pissed', 'fox', 'news'], 'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['.@dccc',
#    'cancel',
#    'primaries.',
#    'fox',
#    'party',
#    'set',
#    '&amp;',
#    'anointed',
#    'man',
#    'jeb',
#    'bush'],
#   'Negative'),
#  (['rubio', 'good', 'job', 'last', 'night.'], 'Positive'),
#  (['good',
#    'sense',
#    'leave',
#    'atlantic',
#    'city."',
#    'back',
#    'jersey,',
#    'trump.',
#    'back.',
#    'the.',
#    'fuck.',
#    'up.'],
#   'Negative'),
#  (['takeaway',
#    'presence',
#    'matters.',
#    'see',
#    'presence',
#    'blend',
#    'believability,',
#    'articulation',
#    'edge',
#    '&amp;',
#    'track',
#    'record.'],
#   'Negative'),
#  (['pushing', 'schools', '&amp;', 'vouchers?'], 'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['asking',
#    'candidates',
#    'questions',
#    'thought',
#    'left',
#    'would',
#    'throw',
#    'nomination.',
#    'smart!'],
#   'Positive'),
#  (['finally', 'opportunity', 'watch', 'honestly', 'speechless...'],
#   'Negative'),
#  (['said', 'whole', 'heck', 'lot,', '"ben', 'carson', 'policy', 'ideas"'],
#   'Negative'),
#  (['taught',
#    'buy',
#    'democracy',
#    'sacrifice',
#    'peoples',
#    'kids',
#    'war!',
#    'make',
#    'whole',
#    'thing',
#    'profitab…'],
#   'Negative'),
#  (['rand', "paul's", 'hair', 'sold', 'calamari', 'debate.'], 'Negative'),
#  (['disgusting',
#    'tone,',
#    'show',
#    'respect',
#    "toward's",
#    'god',
#    'put',
#    'first',
#    'lives!'],
#   'Negative'),
#  (['unborn', 'lives', 'important.', "that's", 'men', 'saying'], 'Positive'),
#  (['wonder',
#    'fifty',
#    'years',
#    'now,',
#    'republicans',
#    'still',
#    'blindly',
#    'cite',
#    'reagan',
#    'justify',
#    'everything',
#    'do.'],
#   'Negative'),
#  (['shocked',
#    'much,but',
#    '"debate"',
#    'questions',
#    'absurd!!with',
#    'shit',
#    'going',
#    'on,',
#    'chose',
#    'try',
#    '&amp;',
#    'start',
#    'fights'],
#   'Negative'),
#  (['last', "night's", 'topics', 'merited', 'attention/which', 'ignored'],
#   'Negative'),
#  (['fox',
#    'news',
#    'keeps',
#    'hammering,',
#    'according',
#    'plan,',
#    'great',
#    'carly',
#    'fiorina',
#    'last',
#    'night—but',
#    'remember',
#    'word',
#    'said.'],
#   'Negative'),
#  (['surgeon',
#    "general's",
#    'warning:',
#    'drinking',
#    'every',
#    'time',
#    'candidate',
#    'says',
#    'something',
#    'stupid',
#    'kill',
#    'you.',
#    'seriously:'],
#   'Negative'),
#  (['many', 'candidates,', 'get', 'get', 'political', 'version', 'auditions.'],
#   'Negative'),
#  (["i'm", 'going', 'bed...@johnkasich', 'gets', 'vote', 'tonight'],
#   'Positive'),
#  (['.@foxnews',
#    'focus',
#    'group:',
#    '"he',
#    'articulate,',
#    'relatable,',
#    '&amp;',
#    'made',
#    'lot',
#    'good',
#    'points."'],
#   'Positive'),
#  (['seems', 'god', 'punished', 'you...'], 'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['jeb',
#    'bush',
#    'promised',
#    'families',
#    'fallen',
#    'troops',
#    'died',
#    'vain.',
#    'victims',
#    'gun',
#    'violen…'],
#   'Negative'),
#  (['debate',
#    'preformances:',
#    'kasich',
#    'rubio',
#    'carson',
#    'christie',
#    'trump',
#    'bush',
#    'cruz',
#    'huckabee',
#    'paul',
#    'walker'],
#   'Positive'),
#  (['think', 'god', 'role', 'running', 'country.'], 'Negative'),
#  (['trump:',
#    'banks',
#    'babies.',
#    'killers.',
#    'hell',
#    'yes',
#    'got',
#    'away',
#    'bad',
#    'deals,',
#    'make',
#    'usa',
#    'scofflaw',
#    'too!'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['tonight',
#    'learned',
#    'thinks',
#    'remove',
#    'civil',
#    'rights',
#    'fight',
#    'terrorism.'],
#   'Negative'),
#  (['…#trump', 'going', 'play', 'game'], 'Positive'),
#  (['carly',
#    'fiorina',
#    'would',
#    'make',
#    'phenomenal',
#    'contrast',
#    'dilapidated',
#    'figure',
#    'dishonest',
#    'corrupted',
#    'hilary',
#    'clinton.'],
#   'Positive'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['shocked--shocked--so',
#    'much',
#    'analysis',
#    'style',
#    'performance,',
#    'nothing',
#    'policy--war,',
#    'rape',
#    'exception,',
#    'cut,',
#    'cut',
#    'cut'],
#   'Negative'),
#  (['jindal',
#    'giving',
#    'excellent',
#    'planned',
#    'parenthood',
#    'answer',
#    'here.'],
#   'Positive'),
#  (['ben', 'carson', 'rocks', 'final', 'thoughts!!!!!'], 'Positive'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['jeb',
#    'bore...er...bush',
#    'really',
#    'perfect',
#    'gop',
#    'candidate.',
#    'boring',
#    'big',
#    'gov',
#    'junior',
#    'executive',
#    'special',
#    'interests.…'],
#   'Negative'),
#  (['know', 'what?', 'fine,', 'fuck', 'it.', 'time', 'vote'], 'Negative'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['sane',
#    'person',
#    'impressed',
#    'w/the',
#    'quality',
#    'moderators',
#    'agenda',
#    'driven',
#    'haters',
#    'gotta',
#    'hate.'],
#   'Negative'),
#  (['correction.', 'thinks', 'worse', 'rosie', "o'donnell..."], 'Negative'),
#  (['says,', 'sake', 'means', '&amp;', 'one', 'better.'], 'Positive'),
#  (['multiple',
#    'shots',
#    'scott',
#    'walker',
#    'nodding',
#    'behind',
#    'ben',
#    'carson',
#    'one',
#    'best',
#    'parts',
#    'real',
#    'strength'],
#   'Positive'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['"the',
#    'real',
#    'story',
#    'collapse',
#    '(@realdonaldtrump)',
#    '(#gopdebate)."'],
#   'Negative'),
#  (["here's", 'clip'], 'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['debates', 'raise', 'ratings', 'fox', 'news', 'afraid', 'trump', 'shows.'],
#   'Negative'),
#  (['showed', 'fleek', 'like'], 'Positive'),
#  (['closing', 'statements:'], 'Negative'),
#  (['whole',
#    'debacle',
#    'insult',
#    'every',
#    'american',
#    'common',
#    'sense',
#    'idea',
#    'history......#gopdebate'],
#   'Negative'),
#  (['rand', 'paul', 'reaching', 'black', 'vote', 'like:'], 'Negative'),
#  (['anti-',
#    'unit',
#    'personal',
#    'destruction',
#    'force',
#    'working',
#    '24/7,',
#    "i'm",
#    'sure.'],
#   'Negative'),
#  (['dare',
#    'candidates',
#    'elaborate',
#    'complex',
#    'policy',
#    'specifics',
#    'debate',
#    'limited',
#    'responses',
#    'ncaa',
#    'sho…'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (["i'm", 'waiting', 'accidentally', 'eat'], 'Negative'),
#  (['gives',
#    'damn?....',
#    "christ's",
#    'sake.',
#    'toughen',
#    'buttercup!',
#    'sick',
#    'politically',
#    'correct',
#    'bull',
#    'chyt'],
#   'Negative'),
#  (['called'], 'Negative'),
#  (['assclown:',
#    "i'm",
#    'reason',
#    'anyone',
#    'even',
#    'talking',
#    'illegal',
#    'immigration.',
#    'keep',
#    'digging,',
#    'donald!'],
#   'Negative'),
#  (['wanted',
#    'say',
#    'good',
#    'luck',
#    'candidates',
#    'taking',
#    'stage',
#    'shortly',
#    'first',
#    'debate',
#    '5:00pm.'],
#   'Positive'),
#  (['moving', 'daniel', 'holden'], 'Negative'),
#  (['"freedom',
#    'free',
#    'must',
#    'fight',
#    'every',
#    'day."',
#    '-@realbencarson',
#    'even',
#    'vote',
#    'guy,',
#    'appreciate'],
#   'Positive'),
#  (['.@borowitzreport', 'assesses', "walker's", 'performance,', 'via'],
#   'Positive'),
#  (['debates', 'raise', 'ratings', 'fox', 'news', 'afraid', 'trump', 'shows.'],
#   'Positive'),
#  (['last', 'night?', 'think', 'commanded', 'stage.', 'harm', 'good'],
#   'Positive'),
#  (['donald', 'trump', 'last', "night's"], 'Positive'),
#  (['rubio:',
#    'trump',
#    'buys',
#    'politicians',
#    'bush:',
#    'gotten',
#    'yet.',
#    'christie:',
#    'yea,',
#    "i'm",
#    'sale',
#    'too.',
#    'trump:',
#    'goo…'],
#   'Negative'),
#  (['running', 'away', 'gop', 'candidates'], 'Negative'),
#  (['90%',
#    'americans',
#    'want',
#    'lawmakers',
#    'close',
#    'background',
#    'check',
#    'loopholes',
#    'gun',
#    'sales.',
#    'candidates',
#    'agree?'],
#   'Negative'),
#  (['straight',
#    'outta',
#    'compton',
#    'commercial',
#    'fox',
#    'news.',
#    'well',
#    'played.'],
#   'Positive'),
#  (['know', 'extraordinary', 'nation', 'is.'], 'Positive'),
#  (['assassination', 'attempt', '...now', 'gop', 'deal', 'consequences'],
#   'Negative'),
#  (['ask',
#    'trump',
#    'legitimate',
#    'question.',
#    'look',
#    "wallace's",
#    'face',
#    'trump',
#    'nails',
#    'it.'],
#   'Positive'),
#  (['care',
#    'well',
#    'compare',
#    'ronald',
#    'reagan!',
#    'promise',
#    'uphold',
#    'constitution,',
#    'please.'],
#   'Negative'),
#  (['would',
#    'nice',
#    'would',
#    'let',
#    '92yr.',
#    'speak',
#    'instead',
#    'interrupting',
#    'her!'],
#   'Positive'),
#  (['else', 'saw', 'horsemen', 'apocalypse', 'last', 'night?'], 'Negative'),
#  (['fear.', 'tried', 'shut', 'message', 'he…'], 'Positive'),
#  (['really',
#    'excited',
#    'campaign',
#    'season.',
#    'googling',
#    'date',
#    'want',
#    'stay',
#    'informed'],
#   'Positive'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['scott',
#    "walker's",
#    '"pro-life"',
#    'stance',
#    'covers',
#    'school',
#    'kids,',
#    'too?'],
#   'Negative'),
#  (['right-wing',
#    'economics',
#    'caused',
#    'mortgage',
#    'crisis',
#    '&amp;',
#    'great',
#    'recession.',
#    'ideas',
#    'proposed',
#    'sol…'],
#   'Negative'),
#  (['great', "let's", 'bunch', 'rich', 'entitled', 'men', 'make', 'decisions'],
#   'Negative'),
#  (['believe', 'miracles??', 'do!', 'kasich', 'came', 'win.'], 'Positive'),
#  (['think',
#    'need',
#    'see',
#    'birth',
#    'certificate',
#    'verify',
#    'age.his',
#    'tweets',
#    'last',
#    'nite',
#    'prove'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['candidate',
#    'received',
#    'word',
#    'god?!',
#    'presidential',
#    'hopefuls?!',
#    'america?!',
#    'christian',
#    'brotherhood',
#    'america'],
#   'Negative'),
#  (['remind',
#    'we’re',
#    'obligated',
#    'import',
#    'third',
#    'world',
#    'welfare',
#    'cases',
#    'wreck',
#    'schools.'],
#   'Negative'),
#  (['anyone', 'else', 'wait', 'snl', 'weekend', 'debate', 'coverage?'],
#   'Negative'),
#  (['number',
#    'aides',
#    'convicted',
#    'felonies',
#    'higher',
#    'number',
#    'voter',
#    'impersonation',
#    'cases',
#    'past',
#    'yrs'],
#   'Negative'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['great',
#    'think',
#    'republican',
#    'party',
#    'whole',
#    'thing.',
#    'great',
#    'candidates!'],
#   'Positive'),
#  (['obviously',
#    'captured',
#    'white',
#    'vote.',
#    'sensible',
#    'americans',
#    'make',
#    'sure',
#    'never',
#    'elected.'],
#   'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['hey',
#    'absolutely',
#    'fearful',
#    "i'm",
#    'lol',
#    'refuse',
#    'ask',
#    'questions!'],
#   'Negative'),
#  (["today's",
#    'gop',
#    'crazy',
#    'white',
#    'dude',
#    'darkened',
#    'theater.',
#    'destroy',
#    'us.'],
#   'Negative'),
#  (['.@realdonaldtrump',
#    'giving',
#    'didn’t',
#    'know',
#    'money',
#    'would',
#    'used',
#    'private',
#    'jets',
#    'going',
#    'world.'],
#   'Positive'),
#  (['basically'], 'Negative'),
#  (['extremely', 'unfair', 'kickoff', 'attack', 'one', 'specific', 'candidate'],
#   'Negative'),
# ...
#  (['wondering',
#    'fox',
#    'debate',
#    'get',
#    'rid',
#    'trump,',
#    'paul,',
#    'cruz,',
#    'carson?'],
#   'Negative'),
#  (['rest',
#    'debate',
#    'embarrassing',
#    'enough,',
#    'god',
#    'question',
#    'rest',
#    'world',
#    'laughs',
#    'us.'],
#   'Negative'),
#  (['need',
#    'order',
#    'another',
#    'green',
#    'apple',
#    'martini',
#    'process',
#    'hell',
#    'happened.'],
#   'Negative'),
#  (['impressed', 'questions', 'last', 'night,', 'dress', 'rocked!!!'],
#   'Positive'),
#  (['donald',
#    'trump’s',
#    'brilliant',
#    'entertainment',
#    'inspired',
#    'hilarious',
#    'memes'],
#   'Negative'),
#  (['gop', 'debate', 'news', 'trump', 'shocks', 'gop', 'faithful'], 'Positive'),
#  (['anyone', 'else', 'want', 'punch', 'chris', 'wallace', 'face?'],
#   'Negative'),
#  (['response', 'tried', 'call', 'sexist:', '"can\'t', 'stump', 'trump!"'],
#   'Negative'),
#  (['drinking',
#    'game:',
#    'take',
#    'shot',
#    'every',
#    'time',
#    'candidate',
#    'talks',
#    'female',
#    'moderator'],
#   'Negative'),
#  (['best', '"reality"', 'show', 'earth'], 'Positive'),
#  (['thanks', 'fox', 'news,', 'raising', 'ratings.'], 'Positive'),
#  (['fox',
#    'cherry',
#    'picking',
#    'candidates.',
#    'jeb',
#    'gets',
#    'softball',
#    'questions.'],
#   'Negative'),
#  (['never', 'thought', 'kasich', 'would', 'sanest', 'guy', 'room.'],
#   'Positive'),
#  (['anyone', 'else', 'wait', 'snl', 'weekend', 'debate', 'coverage?'],
#   'Positive'),
#  (['so,',
#    "there's",
#    'minutes',
#    'left',
#    'debate',
#    'heard',
#    'anything',
#    'police',
#    'brutality,',
#    'mass',
#    'incarceration,',
#    'ra…'],
#   'Negative'),
#  (['“@govmikehuckabee:',
#    'luntz:',
#    '"as',
#    'lines',
#    'up,',
#    'almost',
#    'reach',
#    '100.',
#    'almost',
#    'never',
#    'happens',
#    'dial',
#    'research',
#    'do."',
#    'rigged'],
#   'Negative'),
#  (['real', 'winner', 'last', 'night.'], 'Positive'),
#  (['republicans',
#    '"win"',
#    'last',
#    "night's",
#    'single',
#    'one',
#    'offered',
#    'value',
#    'criterion',
#    'round!'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['gave', 'trump', 'twice', 'much', 'speaking', 'time', 'walker'],
#   'Negative'),
#  (['good',
#    'quick',
#    'analysis',
#    'here:',
#    'republican',
#    'candidates’',
#    'spending',
#    'increases'],
#   'Negative'),
#  (['unless', 'talking', 'schools,', 'air', 'quality,', 'water', 'quality...'],
#   'Negative'),
#  (['political',
#    'junkies',
#    'worse',
#    'football',
#    'fans.',
#    'one',
#    'poor',
#    'debate',
#    'suddenly',
#    'guy',
#    'going',
#    'super',
#    'bowl.'],
#   'Negative'),
#  (['crowd',
#    'cheered',
#    'waterboarding',
#    '...',
#    'think',
#    "i'll",
#    'bed',
#    'rather',
#    'kick',
#    'telly'],
#   'Negative'),
#  (['trump', 'evoked', 'reagan,', 'hey', 'not?', 'republicans', 'help', 'base'],
#   'Negative'),
#  (['yes', 'did!', 'cruz', 'trump', 'trump', 'last', 'night?', 'via'],
#   'Positive'),
#  (['everything', "prostitutes'", "pimps'", 'fault,', 'right', 'huckabee?'],
#   'Negative'),
#  (['tried',
#    'watch',
#    'debate,',
#    'instead',
#    'watched',
#    'millionaires',
#    'play',
#    'grew',
#    'poorest?"'],
#   'Negative'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things"-mike',
#    'huckabee'],
#   'Negative'),
#  (['needs',
#    'get',
#    'kitchen',
#    'make',
#    'sandwich.',
#    'belong',
#    'setting',
#    'him.'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['clear',
#    'looser',
#    'last',
#    'night',
#    'fox',
#    'new',
#    'fair',
#    '&amp;',
#    'balanced',
#    'reputation.'],
#   'Negative'),
#  (['haven’t',
#    'heard',
#    'him,',
#    'personally',
#    'addressed',
#    'god',
#    'many',
#    'times',
#    'tonight',
#    'watching'],
#   'Negative'),
#  (['pro-life',
#    'nonsense',
#    'amusing,',
#    'notion',
#    'could',
#    'come',
#    'alpha',
#    'asshat'],
#   'Negative'),
#  (['sure',
#    'gop',
#    'stage',
#    'looked',
#    'nice',
#    '&amp;',
#    'polished',
#    'america',
#    'tired',
#    'shining',
#    'rolls',
#    'royce',
#    'w/no',
#    'engine'],
#   'Negative'),
#  (['keep',
#    'going',
#    'like',
#    'this-',
#    'even',
#    'bother',
#    'going',
#    'polls.',
#    "that's",
#    'promise!'],
#   'Negative'),
#  (['complaining', 'much', 'targeted', 'think', 'president', 'targeted?'],
#   'Negative'),
#  (['someone', 'send'], 'Negative'),
#  (['trump',
#    'said,',
#    '"megyn,',
#    'ask',
#    'nine',
#    'candidates,',
#    'plan',
#    'support',
#    'win',
#    'nomination."'],
#   'Positive'),
#  (['successful', 'pimp', 'depend', 'social', 'security.'], 'Negative'),
#  (['wow.',
#    'beyond',
#    'delusional...like',
#    'think',
#    'literally',
#    'zero',
#    'people,',
#    'even',
#    'conservative,',
#    'would',
#    'agree'],
#   'Negative'),
#  (['need',
#    'shut',
#    'up,',
#    'sit',
#    'down,',
#    'close',
#    'twitter',
#    'account.',
#    'speak,',
#    'worse',
#    'gets.'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['donates',
#    'u..he',
#    'call',
#    'favor',
#    'years',
#    'later??',
#    'sounds',
#    'like',
#    'thats',
#    'legal?'],
#   'Negative'),
#  (['ask', 'trump', 'question', 'get:', 'squirrel!'], 'Negative'),
#  (['fan', 'mean', 'sponsored'], 'Negative'),
#  (['much', 'like', 'ripping', 'apart.', 'first', 'question', 'dragged', 'on.'],
#   'Negative'),
#  (['miss',
#    'one',
#    'want',
#    'see',
#    'segment',
#    'again?',
#    're-watch',
#    'every',
#    'minute',
#    'playlist'],
#   'Positive'),
#  (['sure', 'was.', 'delivered', 'message', 'well.'], 'Positive'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['dispelled',
#    'fact',
#    'objective',
#    'moderator.',
#    'love',
#    'show,',
#    'moderating,',
#    'much.'],
#   'Negative'),
#  (['walker:', 'god', 'cutting', 'budget.', 'talk', 'him.'], 'Negative'),
#  (['"#fox',
#    'news',
#    'work',
#    'party.',
#    'republican',
#    'party',
#    'works',
#    'fox',
#    'news."',
#    '--david',
#    'frum'],
#   'Negative'),
#  (['start',
#    'evening,',
#    'rnc',
#    'moderators',
#    'dropped',
#    'atom',
#    'bomb',
#    '...trump',
#    'kicked',
#    'thru',
#    'uprights'],
#   'Positive'),
#  (['despite', 'think,', 'person'], 'Negative'),
#  (['killing',
#    'it!',
#    'easily',
#    'crossover',
#    'candidate',
#    'grabbing',
#    'center.'],
#   'Positive'),
#  (['came', 'negro', 'barbershop', 'asked', 'told', 'shut'], 'Negative'),
#  (['finished',
#    'two',
#    'hours',
#    'excellent',
#    'tough',
#    'questions',
#    'without',
#    'single',
#    'one',
#    'properly',
#    'answered',
#    'addressed.'],
#   'Negative'),
#  (['republican',
#    '&amp;',
#    'still',
#    'republican',
#    'debate',
#    'congratulations',
#    'letting',
#    'true',
#    'idiocy',
#    'shine'],
#   'Negative'),
#  (['"she',
#    'mean',
#    'me.',
#    'tried',
#    'calling',
#    'sexist.',
#    'sure',
#    'mansplained',
#    'women',
#    'behave."'],
#   'Negative'),
#  (['think',
#    'rosie',
#    "o'donnell",
#    'needs',
#    'explain',
#    'anything',
#    'fat,',
#    'ugly',
#    'pig',
#    'children.'],
#   'Negative'),
#  (['many',
#    'republicans',
#    'upset',
#    'planned',
#    'parenthood??',
#    'human',
#    'upset',
#    'videos?…'],
#   'Negative'),
#  (['fox', 'news', 'kill', 'momentum', '&amp;', 'may', 'made', 'stronger.'],
#   'Positive'),
#  (['every',
#    'country',
#    'something',
#    'embarrassed',
#    '&amp;',
#    'ashamed',
#    'of.',
#    'americans,',
#    'republican',
#    'party'],
#   'Negative'),
#  (['hugged', 'obama', 'deserve', 'stage', 'tonight.'], 'Negative'),
#  (['playing',
#    'nice',
#    'opposite',
#    'party',
#    'insult...apparently',
#    'cooperation',
#    'leadership',
#    'trait',
#    'anymore'],
#   'Negative'),
#  (['gotta', 'give', 'props.', 'saw', 'ambush', 'calling', 'it.', 'ht…'],
#   'Negative'),
#  (['thank',
#    'cruz!',
#    'finally',
#    'someone',
#    'pledges',
#    'reverse',
#    'every',
#    'obama',
#    'executive',
#    'order',
#    'day',
#    'hard?'],
#   'Positive'),
#  (['carly',
#    'fiorina',
#    'winning',
#    'early',
#    'debate',
#    'may',
#    'done',
#    'campaign',
#    'anyone',
#    'else!'],
#   'Positive'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['conservative',
#    'obama',
#    '(whose',
#    'hand',
#    'held',
#    'blaming',
#    'gop',
#    'sandy!'],
#   'Positive'),
#  (['they’re',
#    'todd',
#    'akin',
#    'now:',
#    'planned',
#    'parenthood',
#    'sting',
#    'backfired',
#    'republicans'],
#   'Negative'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Negative'),
#  (['agree', 'marco', 'rubio', 'helped', 'most.'], 'Positive'),
#  (['disaster', 'sad.', 'one', 'reason', 'watch'], 'Negative'),
#  (['serious', 'hangover', 'today.'], 'Negative'),
#  (['dear',
#    'john',
#    'kasich,',
#    'beat',
#    'republican',
#    'friends',
#    'gay',
#    'tree',
#    'branch'],
#   'Positive'),
#  (['benwikler:',
#    'so,',
#    'senschumer',
#    'throwing',
#    'hat',
#    'ring',
#    'coming',
#    'gop',
#    'side'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['rand',
#    'paul:',
#    'different',
#    'kind',
#    'republican.',
#    'one',
#    "who's",
#    'campaign',
#    'staff',
#    'picked',
#    'fbi',
#    'week.'],
#   'Negative'),
#  (['wondering',
#    'fox',
#    'debate',
#    'get',
#    'rid',
#    'trump,',
#    'paul,',
#    'cruz,',
#    'carson?'],
#   'Negative'),
#  (['fox',
#    'news',
#    'obviously',
#    'trying',
#    'influence',
#    'makeup',
#    'republican',
#    'field.'],
#   'Negative'),
#  (['hey', 'rand,', 'say', 'negotiate', 'one', 'time'], 'Negative'),
#  (['according2my',
#    'twitter',
#    'peeps,',
#    'miss',
#    'thing',
#    'tonight.',
#    'empty',
#    'rhetoric',
#    'w/no',
#    'solutions',
#    'real',
#    'issues.'],
#   'Negative'),
#  (['rubio', 'man', 'right', 'now.', 'well-spoken.', 'impressive.'],
#   'Positive'),
#  (['madness', 'last', 'night.', 'dnc', 'morning....'], 'Negative'),
#  (['dr.',
#    'seriously',
#    'saying',
#    'hillary',
#    'clinton',
#    'trying',
#    'destroy',
#    'america',
#    "that's",
#    'ridiculous',
#    '&amp;',
#    'shame',
#    'lies'],
#   'Negative'),
#  (['ted',
#    'cruz',
#    'looks',
#    'untrustworthy.',
#    'looks',
#    'like',
#    'even',
#    'eyebrows',
#    'trust',
#    'him.'],
#   'Negative'),
#  (['three',
#    'best',
#    'performance',
#    '(in',
#    'order),',
#    'imho:',
#    'carly',
#    'fiorina',
#    '&amp;',
#    'ben',
#    'carson',
#    '&amp;',
#    'marco',
#    'rubio."'],
#   'Positive'),
#  (['needs', 'moderator', 'next', 'debate!'], 'Negative'),
#  (['foxnews', 'tried', 'take', 'gave', 'big', 'win'], 'Negative'),
#  (['rand', "paul's", 'hair', 'sold', 'calamari', 'debate.'], 'Negative'),
#  (['wonder',
#    'candidate',
#    'going',
#    'first',
#    'accidentally',
#    'call',
#    'ben',
#    'carson',
#    '"the',
#    'help"'],
#   'Negative'),
#  (['asked', 'two', 'questions?'], 'Negative'),
#  (['kasich', 'aware', "he's", 'making', 'sense?'], 'Positive'),
#  (['republican', 'debate,', 'newspaper', 'front', 'pages:'], 'Negative'),
#  (['would', 'never', 'know', 'frontrunner', 'watching', 'debate.'],
#   'Negative'),
#  (['chris',
#    'wallace',
#    'ask',
#    'politicans',
#    'finances',
#    'money',
#    'comes',
#    'from?'],
#   'Negative'),
#  (['god,',
#    'wish',
#    'moderating',
#    'debates',
#    'could',
#    'yell',
#    '"points!"',
#    'say',
#    'something',
#    'ridiculous.'],
#   'Negative'),
#  (['attacks', 'care'], 'Negative'),
#  (['candidates', 'attack', 'fox', 'stoping', 'speaking.'], 'Negative'),
#  (['trump', 'would', 'put', 'pos', 'potus'], 'Negative'),
#  (['dear',
#    'fox',
#    'news,',
#    'closing',
#    'argument,',
#    'none',
#    'gop',
#    'candidates',
#    'said',
#    'anything',
#    'help',
#    'suffering',
#    'women',
#    'or…'],
#   'Negative'),
#  (['donald', 'trump', "viewers'", 'attention', 'though', 'probably', 'debate'],
#   'Positive'),
#  (['know', 'giving', 'hugs', 'to?', 'families', 'pearl', 'harbor', 'victims'],
#   'Negative'),
#  (['"the',
#    'purpose',
#    'military',
#    'kill',
#    'people',
#    'break',
#    'things."',
#    'is?',
#    'thought',
#    'protecting',
#    "nation'…"],
#   'Negative'),
#  (["who's",
#    'real',
#    'illegal',
#    'alien',
#    'farrakhan',
#    'immigration',
#    '&amp;',
#    'mexican',
#    'bor...',
#    'via'],
#   'Negative'),
#  (['hey!', 'trump', 'evolved!', 'like', 'obama!'], 'Positive'),
#  (['hour', 'still', 'mention', 'finest', 'avian', 'president.'], 'Negative'),
#  (['clue',
#    'kind',
#    'hard',
#    'work',
#    '&amp;',
#    'commitment',
#    'every',
#    'member',
#    'military',
#    'makes.'],
#   'Negative'),
#  (['republican',
#    'talking',
#    'points:',
#    'iran,',
#    'immigration,',
#    'military.',
#    'hate',
#    'war.',
#    'old',
#    'shit.'],
#   'Negative'),
#  (['donald', 'trump', 'biff', 'back', 'future'], 'Negative'),
#  (["i'd",
#    'really',
#    'like',
#    'see',
#    'long',
#    'candidate',
#    'given',
#    'speak.',
#    'seem',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'all.'],
#   'Negative'),
#  (['perfect', 'remedy', 'hangover'], 'Negative'),
#  (['start',
#    'debate',
#    'loaded',
#    'sexist',
#    'question',
#    'unfair',
#    '&amp;',
#    'disgusting'],
#   'Negative'),
#  (['enjoyed', 'looking', 'forward', 'next.'], 'Positive'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (['yes', 'ridiculous', 'that.'], 'Negative'),
#  (['stupid',
#    'cons',
#    'saying',
#    'comments',
#    'fuel',
#    'rhetoric.',
#    'yeah,',
#    'b/c',
#    'libs',
#    'needed',
#    'reason',
#    'use',
#    'baseless',
#    'accusation.'],
#   'Negative'),
#  (['think',
#    'cruz',
#    'trump',
#    'need',
#    'band',
#    'together',
#    'expose',
#    'set',
#    'job,',
#    'get',
#    'rid',
#    'bush',
#    'rubio,'],
#   'Positive'),
#  (['damn', 'freeloading', 'pimps!'], 'Negative'),
#  (['lived', 'florida', 'years', 'jeb', 'bush', 'swear,', 'more...'],
#   'Negative'),
#  (["can't",
#    'accuse',
#    'bigoted',
#    'token',
#    'woman',
#    '&amp;',
#    'token',
#    'black',
#    '&amp;',
#    'hispanic.'],
#   'Negative'),
#  (['congratulations', '.@ricksantorum', 'gr8', 'job', '2night'], 'Positive'),
#  (['president,', 'always', 'tell', 'truth,', 'said', 'would', 'do.'],
#   'Positive'),
#  (['saw', 'limp', 'balloon.', 'made', 'think', 'last', 'night'], 'Negative'),
#  (['morning',
#    'joe',
#    'crowd',
#    'giving',
#    'fiorina',
#    'false',
#    'sense',
#    'intelligence.',
#    'sarah',
#    'palin',
#    'lighter',
#    'hair'],
#   'Negative'),
#  (['kind',
#    'grossed',
#    'christie',
#    'using',
#    '9/11',
#    'help',
#    'cause.',
#    'feels',
#    'weird',
#    '&amp;',
#    'wrong;',
#    'something',
#    'way',
#    "he's",
#    'doin…'],
#   'Negative'),
#  (['hearing', 'candidates', 'talk', 'god', 'actually', 'terrifying.'],
#   'Negative'),
#  (['perfect', 'remedy', 'hangover'], 'Negative'),
#  (['jeb', 'bush', 'reminds', 'elevator', 'music.', 'hear', 'listen.'],
#   'Negative'),
#  (["here's", 'donald', 'trump', 'channelling', 'inner', 'c*nt'], 'Negative'),
#  (['fox',
#    'news',
#    'admit',
#    'republican',
#    'leader',
#    'right',
#    'mean',
#    'double-digit',
#    'lead'],
#   'Positive'),
#  (['boffo',
#    'early',
#    'ratings',
#    '16%',
#    'households',
#    'tuned',
#    'in,',
#    'old',
#    'record.',
#    'more:'],
#   'Positive'),
#  (['wrong!', 'attacked', 'start.', 'nothing', 'fair', 'balanced.', 'ht…'],
#   'Negative'),
#  (['disappointing',
#    'fox',
#    'news',
#    'conducting',
#    '"fair',
#    '&amp;',
#    'balanced"',
#    'debate.'],
#   'Negative'),
#  (['trump',
#    'said,',
#    '"megyn,',
#    'ask',
#    'nine',
#    'candidates,',
#    'plan',
#    'support',
#    'win',
#    'nomination."'],
#   'Positive'),
#  (['posed', 'adult', 'pictures.should', 'bring', 'up?'], 'Negative'),
#  (['would',
#    'fix',
#    'police',
#    'problem?',
#    'donald',
#    'trump:',
#    'police',
#    'problem?'],
#   'Negative'),
#  ...]

# %%
# Extracting word features
def get_words_in_tweets(tweets):
    all = []
    for (words, sentiment) in tweets:
        all.extend(words)
    return all

def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    features = wordlist.keys()
    return features
w_features = get_word_features(get_words_in_tweets(tweets))

def extract_features(document):
    document_words = set(document)
    features = {}
    for word in w_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
wordcloud_draw(w_features)

# %%
# Training the Naive Bayes classifier
training_set = nltk.classify.apply_features(extract_features,tweets)
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
neg_cnt = 0
pos_cnt = 0
for obj in test_neg: 
    res =  classifier.classify(extract_features(obj.split()))
    if(res == 'Negative'): 
        neg_cnt = neg_cnt + 1
for obj in test_pos: 
    res =  classifier.classify(extract_features(obj.split()))
    if(res == 'Positive'): 
        pos_cnt = pos_cnt + 1
        
print('[Negative]: %s/%s '  % (len(test_neg),neg_cnt))        
print('[Positive]: %s/%s '  % (len(test_pos),pos_cnt))
# Out:
# [Negative]: 853/805
# [Positive]: 213/94
